# %% [markdown]
# # Automate Mining of Line Combinations
# Source: www.dailyfaceoff.com

# %%
from bs4 import BeautifulSoup
import pandas as pd
import pprint
import json

# %%
# First get a list of team names
import requests

url = "https://www.dailyfaceoff.com/teams/"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.80 Safari/537.36',
    'Content-Type': 'text/html',
}

response = requests.get(url, headers=headers)  # get html from url
soup = BeautifulSoup(response.text)            # convert to soup...easier to parse

# add all team names to a list
team_names = []
for tag in soup.find_all("h5", {"class": "team-list-name"}):
    team_names.append(tag.string)
print(team_names)
print(len(team_names))
# Out:
# ['Anaheim Ducks', 'Arizona Coyotes', 'Boston Bruins', 'Buffalo Sabres', 'Calgary Flames', 'Carolina Hurricanes', 'Chicago Blackhawks', 'Colorado Avalanche', 'Columbus Blue Jackets', 'Dallas Stars', 'Detroit Red Wings', 'Edmonton Oilers', 'Florida Panthers', 'Los Angeles Kings', 'Minnesota Wild', 'Montreal Canadiens', 'Nashville Predators', 'New Jersey Devils', 'New York Islanders', 'New York Rangers', 'Ottawa Senators', 'Philadelphia Flyers', 'Pittsburgh Penguins', 'San Jose Sharks', 'St Louis Blues', 'Tampa Bay Lightning', 'Toronto Maple Leafs', 'Vancouver Canucks', 'Vegas Golden Knights', 'Washington Capitals', 'Winnipeg Jets']
# 31

# %%
# create a dictionary that stores lines for each team
line_combinations = {}

for i in range(0, len(team_names)):
    name = team_names[i].rsplit(' ',1)[1]
    
    # create placeholders for forward lines
    for i in range(1,5):
        new_key = name + '_F' + str(i)
        line_combinations[new_key] = {}
    
    # create placeholders for defense pairings
    for i in range(1,4):
        new_key = name + '_D' + str(i)
        line_combinations[new_key] = {}
    
    # create placeholders for pp lines
    for i in range(1,3):
        new_key = name + '_PP' + str(i)
        line_combinations[new_key] = {}
        
    # create placeholders for G lines
    for i in range(1,3):
        new_key = name + '_G' + str(i)
        line_combinations[new_key] = {}
    
    # create placeholder for Injured players
    new_key = name + '_IR'
    line_combinations[new_key] = {}
pprint.pprint(line_combinations)
# Out:
# {'Avalanche_D1': {},
#  'Avalanche_D2': {},
#  'Avalanche_D3': {},
#  'Avalanche_F1': {},
#  'Avalanche_F2': {},
#  'Avalanche_F3': {},
#  'Avalanche_F4': {},
#  'Avalanche_G1': {},
#  'Avalanche_G2': {},
#  'Avalanche_IR': {},
#  'Avalanche_PP1': {},
#  'Avalanche_PP2': {},
#  'Blackhawks_D1': {},
#  'Blackhawks_D2': {},
#  'Blackhawks_D3': {},
#  'Blackhawks_F1': {},
#  'Blackhawks_F2': {},
#  'Blackhawks_F3': {},
#  'Blackhawks_F4': {},
#  'Blackhawks_G1': {},
#  'Blackhawks_G2': {},
#  'Blackhawks_IR': {},
#  'Blackhawks_PP1': {},
#  'Blackhawks_PP2': {},
#  'Blues_D1': {},
#  'Blues_D2': {},
#  'Blues_D3': {},
#  'Blues_F1': {},
#  'Blues_F2': {},
#  'Blues_F3': {},
#  'Blues_F4': {},
#  'Blues_G1': {},
#  'Blues_G2': {},
#  'Blues_IR': {},
#  'Blues_PP1': {},
#  'Blues_PP2': {},
#  'Bruins_D1': {},
#  'Bruins_D2': {},
#  'Bruins_D3': {},
#  'Bruins_F1': {},
#  'Bruins_F2': {},
#  'Bruins_F3': {},
#  'Bruins_F4': {},
#  'Bruins_G1': {},
#  'Bruins_G2': {},
#  'Bruins_IR': {},
#  'Bruins_PP1': {},
#  'Bruins_PP2': {},
#  'Canadiens_D1': {},
#  'Canadiens_D2': {},
#  'Canadiens_D3': {},
#  'Canadiens_F1': {},
#  'Canadiens_F2': {},
#  'Canadiens_F3': {},
#  'Canadiens_F4': {},
#  'Canadiens_G1': {},
#  'Canadiens_G2': {},
#  'Canadiens_IR': {},
#  'Canadiens_PP1': {},
#  'Canadiens_PP2': {},
#  'Canucks_D1': {},
#  'Canucks_D2': {},
#  'Canucks_D3': {},
#  'Canucks_F1': {},
#  'Canucks_F2': {},
#  'Canucks_F3': {},
#  'Canucks_F4': {},
#  'Canucks_G1': {},
#  'Canucks_G2': {},
#  'Canucks_IR': {},
#  'Canucks_PP1': {},
#  'Canucks_PP2': {},
#  'Capitals_D1': {},
#  'Capitals_D2': {},
#  'Capitals_D3': {},
#  'Capitals_F1': {},
#  'Capitals_F2': {},
#  'Capitals_F3': {},
#  'Capitals_F4': {},
#  'Capitals_G1': {},
#  'Capitals_G2': {},
#  'Capitals_IR': {},
#  'Capitals_PP1': {},
#  'Capitals_PP2': {},
#  'Coyotes_D1': {},
#  'Coyotes_D2': {},
#  'Coyotes_D3': {},
#  'Coyotes_F1': {},
#  'Coyotes_F2': {},
#  'Coyotes_F3': {},
#  'Coyotes_F4': {},
#  'Coyotes_G1': {},
#  'Coyotes_G2': {},
#  'Coyotes_IR': {},
#  'Coyotes_PP1': {},
#  'Coyotes_PP2': {},
#  'Devils_D1': {},
#  'Devils_D2': {},
#  'Devils_D3': {},
#  'Devils_F1': {},
#  'Devils_F2': {},
#  'Devils_F3': {},
#  'Devils_F4': {},
#  'Devils_G1': {},
#  'Devils_G2': {},
#  'Devils_IR': {},
#  'Devils_PP1': {},
#  'Devils_PP2': {},
#  'Ducks_D1': {},
#  'Ducks_D2': {},
#  'Ducks_D3': {},
#  'Ducks_F1': {},
#  'Ducks_F2': {},
#  'Ducks_F3': {},
#  'Ducks_F4': {},
#  'Ducks_G1': {},
#  'Ducks_G2': {},
#  'Ducks_IR': {},
#  'Ducks_PP1': {},
#  'Ducks_PP2': {},
#  'Flames_D1': {},
#  'Flames_D2': {},
#  'Flames_D3': {},
#  'Flames_F1': {},
#  'Flames_F2': {},
#  'Flames_F3': {},
#  'Flames_F4': {},
#  'Flames_G1': {},
#  'Flames_G2': {},
#  'Flames_IR': {},
#  'Flames_PP1': {},
#  'Flames_PP2': {},
#  'Flyers_D1': {},
#  'Flyers_D2': {},
#  'Flyers_D3': {},
#  'Flyers_F1': {},
#  'Flyers_F2': {},
#  'Flyers_F3': {},
#  'Flyers_F4': {},
#  'Flyers_G1': {},
#  'Flyers_G2': {},
#  'Flyers_IR': {},
#  'Flyers_PP1': {},
#  'Flyers_PP2': {},
#  'Hurricanes_D1': {},
#  'Hurricanes_D2': {},
#  'Hurricanes_D3': {},
#  'Hurricanes_F1': {},
#  'Hurricanes_F2': {},
#  'Hurricanes_F3': {},
#  'Hurricanes_F4': {},
#  'Hurricanes_G1': {},
#  'Hurricanes_G2': {},
#  'Hurricanes_IR': {},
#  'Hurricanes_PP1': {},
#  'Hurricanes_PP2': {},
#  'Islanders_D1': {},
#  'Islanders_D2': {},
#  'Islanders_D3': {},
#  'Islanders_F1': {},
#  'Islanders_F2': {},
#  'Islanders_F3': {},
#  'Islanders_F4': {},
#  'Islanders_G1': {},
#  'Islanders_G2': {},
#  'Islanders_IR': {},
#  'Islanders_PP1': {},
#  'Islanders_PP2': {},
#  'Jackets_D1': {},
#  'Jackets_D2': {},
#  'Jackets_D3': {},
#  'Jackets_F1': {},
#  'Jackets_F2': {},
#  'Jackets_F3': {},
#  'Jackets_F4': {},
#  'Jackets_G1': {},
#  'Jackets_G2': {},
#  'Jackets_IR': {},
#  'Jackets_PP1': {},
#  'Jackets_PP2': {},
#  'Jets_D1': {},
#  'Jets_D2': {},
#  'Jets_D3': {},
#  'Jets_F1': {},
#  'Jets_F2': {},
#  'Jets_F3': {},
#  'Jets_F4': {},
#  'Jets_G1': {},
#  'Jets_G2': {},
#  'Jets_IR': {},
#  'Jets_PP1': {},
#  'Jets_PP2': {},
#  'Kings_D1': {},
#  'Kings_D2': {},
#  'Kings_D3': {},
#  'Kings_F1': {},
#  'Kings_F2': {},
#  'Kings_F3': {},
#  'Kings_F4': {},
#  'Kings_G1': {},
#  'Kings_G2': {},
#  'Kings_IR': {},
#  'Kings_PP1': {},
#  'Kings_PP2': {},
#  'Knights_D1': {},
#  'Knights_D2': {},
#  'Knights_D3': {},
#  'Knights_F1': {},
#  'Knights_F2': {},
#  'Knights_F3': {},
#  'Knights_F4': {},
#  'Knights_G1': {},
#  'Knights_G2': {},
#  'Knights_IR': {},
#  'Knights_PP1': {},
#  'Knights_PP2': {},
#  'Leafs_D1': {},
#  'Leafs_D2': {},
#  'Leafs_D3': {},
#  'Leafs_F1': {},
#  'Leafs_F2': {},
#  'Leafs_F3': {},
#  'Leafs_F4': {},
#  'Leafs_G1': {},
#  'Leafs_G2': {},
#  'Leafs_IR': {},
#  'Leafs_PP1': {},
#  'Leafs_PP2': {},
#  'Lightning_D1': {},
#  'Lightning_D2': {},
#  'Lightning_D3': {},
#  'Lightning_F1': {},
#  'Lightning_F2': {},
#  'Lightning_F3': {},
#  'Lightning_F4': {},
#  'Lightning_G1': {},
#  'Lightning_G2': {},
#  'Lightning_IR': {},
#  'Lightning_PP1': {},
#  'Lightning_PP2': {},
#  'Oilers_D1': {},
#  'Oilers_D2': {},
#  'Oilers_D3': {},
#  'Oilers_F1': {},
#  'Oilers_F2': {},
#  'Oilers_F3': {},
#  'Oilers_F4': {},
#  'Oilers_G1': {},
#  'Oilers_G2': {},
#  'Oilers_IR': {},
#  'Oilers_PP1': {},
#  'Oilers_PP2': {},
#  'Panthers_D1': {},
#  'Panthers_D2': {},
#  'Panthers_D3': {},
#  'Panthers_F1': {},
#  'Panthers_F2': {},
#  'Panthers_F3': {},
#  'Panthers_F4': {},
#  'Panthers_G1': {},
#  'Panthers_G2': {},
#  'Panthers_IR': {},
#  'Panthers_PP1': {},
#  'Panthers_PP2': {},
#  'Penguins_D1': {},
#  'Penguins_D2': {},
#  'Penguins_D3': {},
#  'Penguins_F1': {},
#  'Penguins_F2': {},
#  'Penguins_F3': {},
#  'Penguins_F4': {},
#  'Penguins_G1': {},
#  'Penguins_G2': {},
#  'Penguins_IR': {},
#  'Penguins_PP1': {},
#  'Penguins_PP2': {},
#  'Predators_D1': {},
#  'Predators_D2': {},
#  'Predators_D3': {},
#  'Predators_F1': {},
#  'Predators_F2': {},
#  'Predators_F3': {},
#  'Predators_F4': {},
#  'Predators_G1': {},
#  'Predators_G2': {},
#  'Predators_IR': {},
#  'Predators_PP1': {},
#  'Predators_PP2': {},
#  'Rangers_D1': {},
#  'Rangers_D2': {},
#  'Rangers_D3': {},
#  'Rangers_F1': {},
#  'Rangers_F2': {},
#  'Rangers_F3': {},
#  'Rangers_F4': {},
#  'Rangers_G1': {},
#  'Rangers_G2': {},
#  'Rangers_IR': {},
#  'Rangers_PP1': {},
#  'Rangers_PP2': {},
#  'Sabres_D1': {},
#  'Sabres_D2': {},
#  'Sabres_D3': {},
#  'Sabres_F1': {},
#  'Sabres_F2': {},
#  'Sabres_F3': {},
#  'Sabres_F4': {},
#  'Sabres_G1': {},
#  'Sabres_G2': {},
#  'Sabres_IR': {},
#  'Sabres_PP1': {},
#  'Sabres_PP2': {},
#  'Senators_D1': {},
#  'Senators_D2': {},
#  'Senators_D3': {},
#  'Senators_F1': {},
#  'Senators_F2': {},
#  'Senators_F3': {},
#  'Senators_F4': {},
#  'Senators_G1': {},
#  'Senators_G2': {},
#  'Senators_IR': {},
#  'Senators_PP1': {},
#  'Senators_PP2': {},
#  'Sharks_D1': {},
#  'Sharks_D2': {},
#  'Sharks_D3': {},
#  'Sharks_F1': {},
#  'Sharks_F2': {},
#  'Sharks_F3': {},
#  'Sharks_F4': {},
#  'Sharks_G1': {},
#  'Sharks_G2': {},
#  'Sharks_IR': {},
#  'Sharks_PP1': {},
#  'Sharks_PP2': {},
#  'Stars_D1': {},
#  'Stars_D2': {},
#  'Stars_D3': {},
#  'Stars_F1': {},
#  'Stars_F2': {},
#  'Stars_F3': {},
#  'Stars_F4': {},
#  'Stars_G1': {},
#  'Stars_G2': {},
#  'Stars_IR': {},
#  'Stars_PP1': {},
#  'Stars_PP2': {},
#  'Wild_D1': {},
#  'Wild_D2': {},
#  'Wild_D3': {},
#  'Wild_F1': {},
#  'Wild_F2': {},
#  'Wild_F3': {},
#  'Wild_F4': {},
#  'Wild_G1': {},
#  'Wild_G2': {},
#  'Wild_IR': {},
#  'Wild_PP1': {},
#  'Wild_PP2': {},
#  'Wings_D1': {},
#  'Wings_D2': {},
#  'Wings_D3': {},
#  'Wings_F1': {},
#  'Wings_F2': {},
#  'Wings_F3': {},
#  'Wings_F4': {},
#  'Wings_G1': {},
#  'Wings_G2': {},
#  'Wings_IR': {},
#  'Wings_PP1': {},
#  'Wings_PP2': {}}

# %%
# get each each group of lines for a team
for i in range(0, len(team_names)):
    # Build URL Request
    url = "https://www.dailyfaceoff.com/teams/" + team_names[i].replace(' ', '-') + '/line-combinations'  # build url
    response = requests.get(url, headers=headers)  # get html from url
    soup = BeautifulSoup(response.text)            # convert to soup...easier to parse
    
    # loop through all player names from webpage
    index = 0  # keep track of index so we know which line a player belongs to
    line = ''
    pos = ''
    name = team_names[i].rsplit(' ',1)[1]
    for tag in soup.find_all("span", {"class": "player-name"}):
        # identify line given order player is in
        if index < 3:    line = name + '_F1'
        elif index < 6:  line = name + '_F2'
        elif index < 9:  line = name + '_F3'
        elif index < 12: line = name + '_F4'
        elif index < 14: line = name + '_D1'
        elif index < 16: line = name + '_D2'
        elif index < 18: line = name + '_D3'
        elif index < 23: line = name + '_PP1'
        elif index < 28: line = name + '_PP2'
        elif index < 29: line = name + '_G1'
        elif index < 30: line = name + '_G2'
        else:            line = name + '_IR'   
            
        # identify position given order player is in
        if index < 12:                     # Fowards
            pos_id = index % 3
            if pos_id == 0:   pos = 'LW'
            elif pos_id == 1: pos = 'C'
            elif pos_id == 2: pos = 'RW'
        elif index < 18:                   # Defensemen
            pos_id = index % 2
            if pos_id == 0:   pos = 'LD'
            elif pos_id == 1: pos = 'RD' 
        elif index < 28:                   # Powerplay
            pos_id = index % 5
            if pos_id == 3:   pos = 'LW'
            elif pos_id == 4: pos = 'C'
            elif pos_id == 0: pos = 'RW'
            elif pos_id == 1: pos = 'LD'
            elif pos_id == 2: pos = 'RD'
        elif index < 30:
            pos = 'G'
        else:
            pos = 'IR'
                
        line_combinations[line][tag.string] = pos
        index = index + 1
#         print(pos + ' ' + line + ' ' + tag.string)

# %%
# verify that line combinations are accurate
pprint.pprint(line_combinations)
# Out:
# {'Avalanche_D1': {'Cale Makar': 'RD', 'Devon Toews': 'LD'},
#  'Avalanche_D2': {'Ryan Graves': 'RD', 'Samuel Girard': 'LD'},
#  'Avalanche_D3': {'Conor Timmins': 'LD', 'Ian Cole': 'RD'},
#  'Avalanche_F1': {'Gabriel Landeskog': 'LW',
#                   'Mikko Rantanen': 'RW',
#                   'Nathan Mackinnon': 'C'},
#  'Avalanche_F2': {'Andre Burakovsky': 'RW',
#                   'Brandon Saad': 'LW',
#                   'Nazem Kadri': 'C'},
#  'Avalanche_F3': {'JT Compher': 'C',
#                   'Joonas Donskoi': 'RW',
#                   'Valeri Nichushkin': 'LW'},
#  'Avalanche_F4': {'Matt Calvert': 'RW',
#                   'Pierre-Édouard Bellemare': 'C',
#                   'Tyson Jost': 'LW'},
#  'Avalanche_G1': {'Philipp Grubauer': 'G'},
#  'Avalanche_G2': {'Pavel Francouz': 'G'},
#  'Avalanche_IR': {'Erik Johnson': 'IR'},
#  'Avalanche_PP1': {'Cale Makar': 'RD',
#                    'Gabriel Landeskog': 'LW',
#                    'Mikko Rantanen': 'RW',
#                    'Nathan Mackinnon': 'LD',
#                    'Nazem Kadri': 'C'},
#  'Avalanche_PP2': {'Andre Burakovsky': 'RW',
#                    'Brandon Saad': 'LW',
#                    'Devon Toews': 'LD',
#                    'JT Compher': 'C',
#                    'Samuel Girard': 'RD'},
#  'Blackhawks_D1': {'Connor Murphy': 'RD', 'Duncan Keith': 'LD'},
#  'Blackhawks_D2': {'Adam Boqvist': 'RD', 'Nikita Zadorov': 'LD'},
#  'Blackhawks_D3': {'Calvin de Haan': 'LD', 'Ian Mitchell': 'RD'},
#  'Blackhawks_F1': {'Alex DeBrincat': 'LW',
#                    'Dylan Strome': 'C',
#                    'Patrick Kane': 'RW'},
#  'Blackhawks_F2': {'Brandon Pirri': 'RW',
#                    'Dominik Kubalik': 'LW',
#                    'Pius Suter': 'C'},
#  'Blackhawks_F3': {'Andrew Shaw': 'RW',
#                    'Lucas Wallmark': 'C',
#                    'Mattias Janmark': 'LW'},
#  'Blackhawks_F4': {'David Kampf': 'C',
#                    'Matthew Highmore': 'LW',
#                    'Ryan Carpenter': 'RW'},
#  'Blackhawks_G1': {'Collin Delia': 'G'},
#  'Blackhawks_G2': {'Malcolm Subban': 'G'},
#  'Blackhawks_IR': {'Alex Nylander': 'IR',
#                    'Jonathan Toews': 'IR',
#                    'Kirby Dach': 'IR'},
#  'Blackhawks_PP1': {'Adam Boqvist': 'RD',
#                     'Alex DeBrincat': 'LD',
#                     'Andrew Shaw': 'LW',
#                     'Dylan Strome': 'C',
#                     'Patrick Kane': 'RW'},
#  'Blackhawks_PP2': {'Brandon Pirri': 'RW',
#                     'Dominik Kubalik': 'LD',
#                     'Duncan Keith': 'RD',
#                     'Lucas Wallmark': 'C',
#                     'Pius Suter': 'LW'},
#  'Blues_D1': {'Colton Parayko': 'RD', 'Torey Krug': 'LD'},
#  'Blues_D2': {'Justin Faulk': 'RD', 'Marco Scandella': 'LD'},
#  'Blues_D3': {'Robert Bortuzzo': 'RD', 'Vince Dunn': 'LD'},
#  'Blues_F1': {'Brayden Schenn': 'LW',
#               'David Perron': 'RW',
#               "Ryan O'Reilly": 'C'},
#  'Blues_F2': {'Jaden Schwartz': 'LW',
#               'Mike Hoffman': 'RW',
#               'Robert Thomas': 'C'},
#  'Blues_F3': {'Jordan Kyrou': 'RW', 'Tyler Bozak': 'C', 'Zach Sanford': 'LW'},
#  'Blues_F4': {'Ivan Barbashev': 'C',
#               'Kyle Clifford': 'LW',
#               'Oskar Sundqvist': 'RW'},
#  'Blues_G1': {'Jordan Binnington': 'G'},
#  'Blues_G2': {'Ville Husso': 'G'},
#  'Blues_IR': {'Jay Bouwmeester': 'IR', 'Vladimir Tarasenko': 'IR'},
#  'Blues_PP1': {'Brayden Schenn': 'LW',
#                'David Perron': 'RW',
#                'Mike Hoffman': 'LD',
#                "Ryan O'Reilly": 'C',
#                'Torey Krug': 'RD'},
#  'Blues_PP2': {'Colton Parayko': 'LD',
#                'Jaden Schwartz': 'LW',
#                'Robert Thomas': 'RW',
#                'Tyler Bozak': 'C',
#                'Vince Dunn': 'RD'},
#  'Bruins_D1': {'Charlie McAvoy': 'RD', 'Jeremy Lauzon': 'LD'},
#  'Bruins_D2': {'Brandon Carlo': 'RD', 'Matt Grzelcyk': 'LD'},
#  'Bruins_D3': {'Jakub Zboril': 'LD', 'Kevan Miller': 'RD'},
#  'Bruins_F1': {'Brad Marchand': 'LW',
#                'Jack Studnicka': 'RW',
#                'Patrice Bergeron': 'C'},
#  'Bruins_F2': {'David Krejci': 'C', 'Jake DeBrusk': 'LW', 'Ondrej Kase': 'RW'},
#  'Bruins_F3': {'Anders Bjork': 'RW',
#                'Charlie Coyle': 'C',
#                'Nick Ritchie': 'LW'},
#  'Bruins_F4': {'Chris Wagner': 'RW',
#                'Sean Kuraly': 'C',
#                'Trent Frederic': 'LW'},
#  'Bruins_G1': {'Tuukka Rask': 'G'},
#  'Bruins_G2': {'Jaroslav Halak': 'G'},
#  'Bruins_IR': {'Craig Smith': 'IR', 'David Pastrnak': 'IR'},
#  'Bruins_PP1': {'Brad Marchand': 'RW',
#                 'Charlie Coyle': 'LW',
#                 'David Krejci': 'RD',
#                 'Matt Grzelcyk': 'LD',
#                 'Patrice Bergeron': 'C'},
#  'Bruins_PP2': {'Charlie McAvoy': 'LD',
#                 'Jack Studnicka': 'RD',
#                 'Jake DeBrusk': 'RW',
#                 'Nick Ritchie': 'LW',
#                 'Ondrej Kase': 'C'},
#  'Canadiens_D1': {'Ben Chiarot': 'LD', 'Shea Weber': 'RD'},
#  'Canadiens_D2': {'Jeff Petry': 'RD', 'Joel Edmundson': 'LD'},
#  'Canadiens_D3': {'Alexander Romanov': 'RD', 'Brett Kulak': 'LD'},
#  'Canadiens_F1': {'Brendan Gallagher': 'RW',
#                   'Phillip Danault': 'C',
#                   'Tomas Tatar': 'LW'},
#  'Canadiens_F2': {'Jonathan Drouin': 'LW',
#                   'Josh Anderson': 'RW',
#                   'Nick Suzuki': 'C'},
#  'Canadiens_F3': {'Jesperi Kotkaniemi': 'C',
#                   'Joel Armia': 'RW',
#                   'Tyler Toffoli': 'LW'},
#  'Canadiens_F4': {'Artturi Lehkonen': 'LW',
#                   'Jake Evans': 'C',
#                   'Paul Byron': 'RW'},
#  'Canadiens_G1': {'Carey Price': 'G'},
#  'Canadiens_G2': {'Jake Allen': 'G'},
#  'Canadiens_IR': {},
#  'Canadiens_PP1': {'Jeff Petry': 'RD',
#                    'Jonathan Drouin': 'RW',
#                    'Nick Suzuki': 'C',
#                    'Shea Weber': 'LD',
#                    'Tyler Toffoli': 'LW'},
#  'Canadiens_PP2': {'Alexander Romanov': 'RD',
#                    'Brendan Gallagher': 'RW',
#                    'Jesperi Kotkaniemi': 'C',
#                    'Josh Anderson': 'LW',
#                    'Tomas Tatar': 'LD'},
#  'Canucks_D1': {'Alexander Edler': 'LD', 'Nate Schmidt': 'RD'},
#  'Canucks_D2': {'Quinn Hughes': 'LD', 'Travis Hamonic': 'RD'},
#  'Canucks_D3': {'Olli Juolevi': 'LD', 'Tyler Myers': 'RD'},
#  'Canucks_F1': {'Brock Boeser': 'LW',
#                 'Elias Pettersson': 'C',
#                 'Jake Virtanen': 'RW'},
#  'Canucks_F2': {'Bo Horvat': 'C',
#                 'Nils Hoglander': 'RW',
#                 'Tanner Pearson': 'LW'},
#  'Canucks_F3': {'Adam Gaudette': 'C',
#                 'Antoine Roussel': 'LW',
#                 'Zack MacEwen': 'RW'},
#  'Canucks_F4': {'Brandon Sutter': 'RW', 'Jay Beagle': 'C', 'Tyler Motte': 'LW'},
#  'Canucks_G1': {'Thatcher Demko': 'G'},
#  'Canucks_G2': {'Braden Holtby': 'G'},
#  'Canucks_IR': {'J.T. Miller': 'IR',
#                 'Jordie Benn': 'IR',
#                 'Micheal Ferland': 'IR'},
#  'Canucks_PP1': {'Bo Horvat': 'C',
#                  'Brock Boeser': 'LW',
#                  'Elias Pettersson': 'RD',
#                  'Nils Hoglander': 'RW',
#                  'Quinn Hughes': 'LD'},
#  'Canucks_PP2': {'Adam Gaudette': 'C',
#                  'Jake Virtanen': 'LW',
#                  'Nate Schmidt': 'RD',
#                  'Tanner Pearson': 'LD',
#                  'Tyler Motte': 'RW'},
#  'Capitals_D1': {'Dmitri Orlov': 'LD', 'John Carlson': 'RD'},
#  'Capitals_D2': {'Brenden Dillon': 'LD', 'Justin Schultz': 'RD'},
#  'Capitals_D3': {'Nick Jensen': 'RD', 'Zdeno Chara': 'LD'},
#  'Capitals_F1': {'Alex Ovechkin': 'LW',
#                  'Nicklas Backstrom': 'C',
#                  'T.J. Oshie': 'RW'},
#  'Capitals_F2': {'Evgeny Kuznetsov': 'C',
#                  'Jakub Vrana': 'LW',
#                  'Tom Wilson': 'RW'},
#  'Capitals_F3': {'Conor Sheary': 'RW',
#                  'Lars Eller': 'C',
#                  'Richard Panik': 'LW'},
#  'Capitals_F4': {'Carl Hagelin': 'LW',
#                  'Garnet Hathaway': 'RW',
#                  'Nic Dowd': 'C'},
#  'Capitals_G1': {'Ilya Samsonov': 'G'},
#  'Capitals_G2': {'Vitek Vanecek': 'G'},
#  'Capitals_IR': {},
#  'Capitals_PP1': {'Alex Ovechkin': 'LD',
#                   'Evgeny Kuznetsov': 'RW',
#                   'John Carlson': 'RD',
#                   'Nicklas Backstrom': 'C',
#                   'T.J. Oshie': 'LW'},
#  'Capitals_PP2': {'Alex Ovechkin': 'LD',
#                   'Jakub Vrana': 'C',
#                   'Justin Schultz': 'RD',
#                   'Richard Panik': 'RW',
#                   'Tom Wilson': 'LW'},
#  'Coyotes_D1': {'Jason Demers': 'RD', 'Oliver Ekman-Larsson': 'LD'},
#  'Coyotes_D2': {'Alex Goligoski': 'RD', 'Jakob Chychrun': 'LD'},
#  'Coyotes_D3': {'Jordan Oesterle': 'LD', 'Niklas Hjalmarsson': 'RD'},
#  'Coyotes_F1': {'Barrett Hayton': 'LW',
#                 'Conor Garland': 'RW',
#                 'Nick Schmaltz': 'C'},
#  'Coyotes_F2': {'Christian Dvorak': 'C',
#                 'Drake Caggiula': 'LW',
#                 'Phil Kessel': 'RW'},
#  'Coyotes_F3': {'Clayton Keller': 'LW',
#                 'Derick Brassard': 'C',
#                 'Tyler Pitlick': 'RW'},
#  'Coyotes_F4': {'Christian Fischer': 'RW',
#                 'Johan Larsson': 'C',
#                 'Lawson Crouse': 'LW'},
#  'Coyotes_G1': {'Darcy Kuemper': 'G'},
#  'Coyotes_G2': {'Antti Raanta': 'G'},
#  'Coyotes_IR': {},
#  'Coyotes_PP1': {'Christian Dvorak': 'C',
#                  'Clayton Keller': 'RW',
#                  'Drake Caggiula': 'LW',
#                  'Oliver Ekman-Larsson': 'RD',
#                  'Phil Kessel': 'LD'},
#  'Coyotes_PP2': {'Alex Goligoski': 'RD',
#                  'Conor Garland': 'RW',
#                  'Derick Brassard': 'LW',
#                  'Jakob Chychrun': 'LD',
#                  'Nick Schmaltz': 'C'},
#  'Devils_D1': {'P.K. Subban': 'RD', 'Ryan Murray': 'LD'},
#  'Devils_D2': {'Damon Severson': 'RD', 'Dmitry Kulikov': 'LD'},
#  'Devils_D3': {'Matt Tennyson': 'RD', 'Ty Smith': 'LD'},
#  'Devils_F1': {'Jack Hughes': 'C',
#                'Kyle Palmieri': 'RW',
#                'Yegor Sharangovich': 'LW'},
#  'Devils_F2': {'Andreas Johnsson': 'LW',
#                'Nikita Gusev': 'RW',
#                'Pavel Zacha': 'C'},
#  'Devils_F3': {'Jesper Boqvist': 'RW', 'Miles Wood': 'LW', 'Travis Zajac': 'C'},
#  'Devils_F4': {'Janne Kuokkanen': 'LW',
#                'Michael McLeod': 'C',
#                'Nathan Bastian': 'RW'},
#  'Devils_G1': {'Mackenzie Blackwood': 'G'},
#  'Devils_G2': {'Scott Wedgewood': 'G'},
#  'Devils_IR': {'Nico Hischier': 'IR'},
#  'Devils_PP1': {'Jack Hughes': 'C',
#                 'Kyle Palmieri': 'RW',
#                 'Nikita Gusev': 'LD',
#                 'P.K. Subban': 'RD',
#                 'Pavel Zacha': 'LW'},
#  'Devils_PP2': {'Andreas Johnsson': 'RW',
#                 'Damon Severson': 'RD',
#                 'Jesper Boqvist': 'C',
#                 'Miles Wood': 'LW',
#                 'Ty Smith': 'LD'},
#  'Ducks_D1': {'Hampus Lindholm': 'LD', 'Kevin Shattenkirk': 'RD'},
#  'Ducks_D2': {'Cam Fowler': 'LD', 'Josh Manson': 'RD'},
#  'Ducks_D3': {'Jacob Larsson': 'LD', 'Jani Hakanpaa': 'RD'},
#  'Ducks_F1': {'Adam Henrique': 'C',
#               'Jakob Silfverberg': 'LW',
#               'Rickard Rakell': 'RW'},
#  'Ducks_F2': {'Danton Heinen': 'RW',
#               'Isac Lundestrom': 'LW',
#               'Ryan Getzlaf': 'C'},
#  'Ducks_F3': {'Maxime Comtois': 'LW', 'Sam Steel': 'C', 'Troy Terry': 'RW'},
#  'Ducks_F4': {'Carter Rowney': 'RW',
#               'Derek Grant': 'C',
#               'Nicolas Deslauriers': 'LW'},
#  'Ducks_G1': {'John Gibson': 'G'},
#  'Ducks_G2': {'Ryan Miller': 'G'},
#  'Ducks_IR': {'Ryan Kesler': 'IR'},
#  'Ducks_PP1': {'Adam Henrique': 'C',
#                'Derek Grant': 'LW',
#                'Jakob Silfverberg': 'RW',
#                'Kevin Shattenkirk': 'RD',
#                'Rickard Rakell': 'LD'},
#  'Ducks_PP2': {'Cam Fowler': 'RD',
#                'Danton Heinen': 'RW',
#                'Maxime Comtois': 'LW',
#                'Ryan Getzlaf': 'LD',
#                'Sam Steel': 'C'},
#  'Flames_D1': {'Mark Giordano': 'LD', 'Rasmus Andersson': 'RD'},
#  'Flames_D2': {'Chris Tanev': 'RD', 'Noah Hanifin': 'LD'},
#  'Flames_D3': {'Juuso Valimaki': 'LD', 'Nikita Nesterov': 'RD'},
#  'Flames_F1': {'Dillon Dube': 'RW',
#                'Elias Lindholm': 'C',
#                'Matthew Tkachuk': 'LW'},
#  'Flames_F2': {'Johnny Gaudreau': 'LW',
#                'Josh Leivo': 'RW',
#                'Sean Monahan': 'C'},
#  'Flames_F3': {'Andrew Mangiapane': 'LW',
#                'Derek Ryan': 'RW',
#                'Mikael Backlund': 'C'},
#  'Flames_F4': {'Joakim Nordstrom': 'RW',
#                'Milan Lucic': 'LW',
#                'Sam Bennett': 'C'},
#  'Flames_G1': {'Jacob Markstrom': 'G'},
#  'Flames_G2': {'David Rittich': 'G'},
#  'Flames_IR': {},
#  'Flames_PP1': {'Elias Lindholm': 'LD',
#                 'Johnny Gaudreau': 'RW',
#                 'Matthew Tkachuk': 'LW',
#                 'Rasmus Andersson': 'RD',
#                 'Sean Monahan': 'C'},
#  'Flames_PP2': {'Andrew Mangiapane': 'LD',
#                 'Dillon Dube': 'RW',
#                 'Mark Giordano': 'RD',
#                 'Mikael Backlund': 'C',
#                 'Milan Lucic': 'LW'},
#  'Flyers_D1': {'Ivan Provorov': 'LD', 'Justin Braun': 'RD'},
#  'Flyers_D2': {'Philippe Myers': 'RD', 'Travis Sanheim': 'LD'},
#  'Flyers_D3': {'Erik Gustafsson': 'RD', 'Robert Hagg': 'LD'},
#  'Flyers_F1': {'Oskar Lindblom': 'LW',
#                'Sean Couturier': 'C',
#                'Travis Konecny': 'RW'},
#  'Flyers_F2': {'Claude Giroux': 'LW', 'Joel Farabee': 'RW', 'Kevin Hayes': 'C'},
#  'Flyers_F3': {'Jakub Voracek': 'RW',
#                'James van Riemsdyk': 'LW',
#                'Nolan Patrick': 'C'},
#  'Flyers_F4': {'Michael Raffl': 'LW',
#                'Nicolas Aube-Kubel': 'RW',
#                'Scott Laughton': 'C'},
#  'Flyers_G1': {'Carter Hart': 'G'},
#  'Flyers_G2': {'Brian Elliott': 'G'},
#  'Flyers_IR': {},
#  'Flyers_PP1': {'Claude Giroux': 'LD',
#                 'Ivan Provorov': 'RD',
#                 'Kevin Hayes': 'LW',
#                 'Sean Couturier': 'C',
#                 'Travis Konecny': 'RW'},
#  'Flyers_PP2': {'Erik Gustafsson': 'LD',
#                 'Jakub Voracek': 'RD',
#                 'James van Riemsdyk': 'LW',
#                 'Joel Farabee': 'RW',
#                 'Nolan Patrick': 'C'},
#  'Hurricanes_D1': {'Dougie Hamilton': 'RD', 'Jaccob Slavin': 'LD'},
#  'Hurricanes_D2': {'Brady Skjei': 'LD', 'Brett Pesce': 'RD'},
#  'Hurricanes_D3': {'Haydn Fleury': 'RD', 'Jake Gardiner': 'LD'},
#  'Hurricanes_F1': {'Nino Niederreiter': 'LW',
#                    'Sebastian Aho': 'C',
#                    'Teuvo Teravainen': 'RW'},
#  'Hurricanes_F2': {'Andrei Svechnikov': 'LW',
#                    'Jordan Staal': 'C',
#                    'Martin Necas': 'RW'},
#  'Hurricanes_F3': {'Jesper Fast': 'RW',
#                    'Vincent Trocheck': 'C',
#                    'Warren Foegele': 'LW'},
#  'Hurricanes_F4': {'Brock McGinn': 'RW',
#                    'Jordan Martinook': 'C',
#                    'Ryan Dzingel': 'LW'},
#  'Hurricanes_G1': {'Petr Mrazek': 'G'},
#  'Hurricanes_G2': {'James Reimer': 'G'},
#  'Hurricanes_IR': {},
#  'Hurricanes_PP1': {'Andrei Svechnikov': 'RD',
#                     'Dougie Hamilton': 'LD',
#                     'Sebastian Aho': 'C',
#                     'Teuvo Teravainen': 'RW',
#                     'Vincent Trocheck': 'LW'},
#  'Hurricanes_PP2': {'Jake Gardiner': 'RD',
#                     'Jordan Staal': 'C',
#                     'Martin Necas': 'RW',
#                     'Nino Niederreiter': 'LW',
#                     'Ryan Dzingel': 'LD'},
#  'Islanders_D1': {'Adam Pelech': 'LD', 'Ryan Pulock': 'RD'},
#  'Islanders_D2': {'Nick Leddy': 'LD', 'Scott Mayfield': 'RD'},
#  'Islanders_D3': {'Andy Greene': 'LD', 'Noah Dobson': 'RD'},
#  'Islanders_F1': {'Anders Lee': 'LW',
#                   'Jordan Eberle': 'RW',
#                   'Mathew Barzal': 'C'},
#  'Islanders_F2': {'Anthony Beauvillier': 'LW',
#                   'Brock Nelson': 'C',
#                   'Josh Bailey': 'RW'},
#  'Islanders_F3': {'Jean-Gabriel Pageau': 'C',
#                   'Kieffer Bellows': 'LW',
#                   'Ross Johnston': 'RW'},
#  'Islanders_F4': {'Cal Clutterbuck': 'RW',
#                   'Casey Cizikas': 'C',
#                   'Matt Martin': 'LW'},
#  'Islanders_G1': {'Semyon Varlamov': 'G'},
#  'Islanders_G2': {'Ilya Sorokin': 'G'},
#  'Islanders_IR': {'Johnny Boychuk': 'IR', 'Michael Dal Colle': 'IR'},
#  'Islanders_PP1': {'Anders Lee': 'LW',
#                    'Jordan Eberle': 'RW',
#                    'Mathew Barzal': 'C',
#                    'Noah Dobson': 'RD',
#                    'Ryan Pulock': 'LD'},
#  'Islanders_PP2': {'Anthony Beauvillier': 'RD',
#                    'Brock Nelson': 'C',
#                    'Jean-Gabriel Pageau': 'LW',
#                    'Josh Bailey': 'RW',
#                    'Nick Leddy': 'LD'},
#  'Jackets_D1': {'Seth Jones': 'RD', 'Zach Werenski': 'LD'},
#  'Jackets_D2': {'David Savard': 'RD', 'Vladislav Gavrikov': 'LD'},
#  'Jackets_D3': {'Dean Kukan': 'RD', 'Michael Del Zotto': 'LD'},
#  'Jackets_F1': {'Mikhail Grigorenko': 'LW',
#                 'Oliver Bjorkstrand': 'RW',
#                 'Pierre-Luc Dubois': 'C'},
#  'Jackets_F2': {'Cam Atkinson': 'RW', 'Max Domi': 'C', 'Nick Foligno': 'LW'},
#  'Jackets_F3': {'Alexandre Texier': 'C',
#                 'Boone Jenner': 'LW',
#                 'Emil Bemstrom': 'RW'},
#  'Jackets_F4': {'Eric Robinson': 'RW', 'Liam Foudy': 'LW', 'Riley Nash': 'C'},
#  'Jackets_G1': {'Elvis Merzlikins': 'G'},
#  'Jackets_G2': {'Joonas Korpisalo': 'G'},
#  'Jackets_IR': {'Gustav Nyquist': 'IR', 'Mikko Koivu': 'IR'},
#  'Jackets_PP1': {'Alexandre Texier': 'LW',
#                  'Emil Bemstrom': 'LD',
#                  'Max Domi': 'RW',
#                  'Mikhail Grigorenko': 'C',
#                  'Zach Werenski': 'RD'},
#  'Jackets_PP2': {'Cam Atkinson': 'LD',
#                  'Nick Foligno': 'C',
#                  'Oliver Bjorkstrand': 'RW',
#                  'Pierre-Luc Dubois': 'LW',
#                  'Seth Jones': 'RD'},
#  'Jets_D1': {'Josh Morrissey': 'LD', 'Tucker Poolman': 'RD'},
#  'Jets_D2': {'Derek Forbort': 'LD', 'Neal Pionk': 'RD'},
#  'Jets_D3': {'Nathan Beaulieu': 'LD', 'Sami Niku': 'RD'},
#  'Jets_F1': {'Blake Wheeler': 'RW',
#              'Mark Scheifele': 'C',
#              'Nikolaj Ehlers': 'LW'},
#  'Jets_F2': {'Kyle Connor': 'LW', 'Patrik Laine': 'RW', 'Paul Stastny': 'C'},
#  'Jets_F3': {'Adam Lowry': 'C', 'Andrew Copp': 'LW', 'Mason Appleton': 'RW'},
#  'Jets_F4': {'Mathieu Perreault': 'LW',
#              'Nate Thompson': 'C',
#              'Trevor Lewis': 'RW'},
#  'Jets_G1': {'Connor Hellebuyck': 'G'},
#  'Jets_G2': {'Laurent Brossoit': 'G'},
#  'Jets_IR': {'Bryan Little': 'IR', 'Dylan DeMelo': 'IR'},
#  'Jets_PP1': {'Blake Wheeler': 'LW',
#               'Kyle Connor': 'RW',
#               'Mark Scheifele': 'C',
#               'Neal Pionk': 'RD',
#               'Patrik Laine': 'LD'},
#  'Jets_PP2': {'Josh Morrissey': 'LD',
#               'Mark Scheifele': 'RD',
#               'Mathieu Perreault': 'LW',
#               'Nikolaj Ehlers': 'RW',
#               'Paul Stastny': 'C'},
#  'Kings_D1': {'Drew Doughty': 'RD', 'Olli Maatta': 'LD'},
#  'Kings_D2': {'Matt Roy': 'RD', 'Mikey Anderson': 'LD'},
#  'Kings_D3': {'Kale Clague': 'LD', 'Mark Alt': 'RD'},
#  'Kings_F1': {'Alex Iafallo': 'LW', 'Anze Kopitar': 'C', 'Dustin Brown': 'RW'},
#  'Kings_F2': {'Andreas Athanasiou': 'LW',
#               'Blake Lizotte': 'C',
#               'Jeff Carter': 'RW'},
#  'Kings_F3': {'Adrian Kempe': 'LW',
#               'Austin Wagner': 'RW',
#               'Gabriel Vilardi': 'C'},
#  'Kings_F4': {'Matt Luff': 'RW', 'Mike Amadio': 'C', 'Trevor Moore': 'LW'},
#  'Kings_G1': {'Jonathan Quick': 'G'},
#  'Kings_G2': {'Troy Grosenick': 'G'},
#  'Kings_IR': {'Cal Petersen': 'IR',
#               'Kurtis MacDermid': 'IR',
#               'Martin Frk': 'IR',
#               'Sean Walker': 'IR'},
#  'Kings_PP1': {'Adrian Kempe': 'RW',
#                'Alex Iafallo': 'LD',
#                'Anze Kopitar': 'C',
#                'Drew Doughty': 'RD',
#                'Dustin Brown': 'LW'},
#  'Kings_PP2': {'Andreas Athanasiou': 'RD',
#                'Blake Lizotte': 'RW',
#                'Gabriel Vilardi': 'C',
#                'Jeff Carter': 'LW',
#                'Mikey Anderson': 'LD'},
#  'Knights_D1': {'Alex Pietrangelo': 'RD', 'Brayden McNabb': 'LD'},
#  'Knights_D2': {'Alec Martinez': 'LD', 'Shea Theodore': 'RD'},
#  'Knights_D3': {'Keegan Kolesar': 'LD', 'Zach Whitecloud': 'RD'},
#  'Knights_F1': {'Chandler Stephenson': 'C',
#                 'Mark Stone': 'RW',
#                 'Max Pacioretty': 'LW'},
#  'Knights_F2': {'Jonathan Marchessault': 'LW',
#                 'Reilly Smith': 'RW',
#                 'William Karlsson': 'C'},
#  'Knights_F3': {'Alex Tuch': 'LW', 'Cody Glass': 'C', 'Nicolas Roy': 'RW'},
#  'Knights_F4': {'Ryan Reaves': 'RW', 'Tomas Nosek': 'C', 'Will Carrier': 'LW'},
#  'Knights_G1': {'Robin Lehner': 'G'},
#  'Knights_G2': {'Marc-Andre Fleury': 'G'},
#  'Knights_IR': {},
#  'Knights_PP1': {'Alex Pietrangelo': 'LD',
#                  'Cody Glass': 'RW',
#                  'Mark Stone': 'LW',
#                  'Max Pacioretty': 'RD',
#                  'William Karlsson': 'C'},
#  'Knights_PP2': {'Alec Martinez': 'RD',
#                  'Alex Tuch': 'LW',
#                  'Jonathan Marchessault': 'C',
#                  'Reilly Smith': 'RW',
#                  'Shea Theodore': 'LD'},
#  'Leafs_D1': {'Morgan Rielly': 'LD', 'T.J. Brodie': 'RD'},
#  'Leafs_D2': {'Jake Muzzin': 'LD', 'Justin Holl': 'RD'},
#  'Leafs_D3': {'Travis Dermott': 'LD', 'Zach Bogosian': 'RD'},
#  'Leafs_F1': {'Auston Matthews': 'C',
#               'Joe Thornton': 'LW',
#               'Mitch Marner': 'RW'},
#  'Leafs_F2': {'Jimmy Vesey': 'LW',
#               'John Tavares': 'C',
#               'William Nylander': 'RW'},
#  'Leafs_F3': {'Alexander Kerfoot': 'C',
#               'Ilya Mikheyev': 'LW',
#               'Zach Hyman': 'RW'},
#  'Leafs_F4': {'Alexander Barabanov': 'LW',
#               'Jason Spezza': 'C',
#               'Wayne Simmonds': 'RW'},
#  'Leafs_G1': {'Frederik Andersen': 'G'},
#  'Leafs_G2': {'Jack Campbell': 'G'},
#  'Leafs_IR': {},
#  'Leafs_PP1': {'Auston Matthews': 'RD',
#                'Joe Thornton': 'C',
#                'Mitch Marner': 'RW',
#                'Morgan Rielly': 'LD',
#                'Wayne Simmonds': 'LW'},
#  'Leafs_PP2': {'Jason Spezza': 'RW',
#                'John Tavares': 'C',
#                'T.J. Brodie': 'RD',
#                'William Nylander': 'LD',
#                'Zach Hyman': 'LW'},
#  'Lightning_D1': {'Jan Rutta': 'RD', 'Victor Hedman': 'LD'},
#  'Lightning_D2': {'Erik Cernak': 'RD', 'Ryan McDonagh': 'LD'},
#  'Lightning_D3': {'Luke Schenn': 'RD', 'Mikhail Sergachev': 'LD'},
#  'Lightning_F1': {'Brayden Point': 'C',
#                   'Ondrej Palat': 'LW',
#                   'Steven Stamkos': 'RW'},
#  'Lightning_F2': {'Alex Killorn': 'LW',
#                   'Anthony Cirelli': 'C',
#                   'Tyler Johnson': 'RW'},
#  'Lightning_F3': {'Barclay Goodrow': 'RW',
#                   'Blake Coleman': 'LW',
#                   'Yanni Gourde': 'C'},
#  'Lightning_F4': {'Mathieu Joseph': 'RW',
#                   'Mitchell Stephens': 'C',
#                   'Patrick Maroon': 'LW'},
#  'Lightning_G1': {'Andrei Vasilevskiy': 'G'},
#  'Lightning_G2': {'Curtis McElhinney': 'G'},
#  'Lightning_IR': {'Anders Nilsson': 'IR',
#                   'Marian Gaborik': 'IR',
#                   'Nikita Kucherov': 'IR'},
#  'Lightning_PP1': {'Alex Killorn': 'LW',
#                    'Brayden Point': 'C',
#                    'Ondrej Palat': 'RW',
#                    'Steven Stamkos': 'LD',
#                    'Victor Hedman': 'RD'},
#  'Lightning_PP2': {'Anthony Cirelli': 'C',
#                    'Mikhail Sergachev': 'LD',
#                    'Patrick Maroon': 'LW',
#                    'Tyler Johnson': 'RD',
#                    'Yanni Gourde': 'RW'},
#  'Oilers_D1': {'Darnell Nurse': 'LD', 'Ethan Bear': 'RD'},
#  'Oilers_D2': {'Adam Larsson': 'RD', 'Caleb Jones': 'LD'},
#  'Oilers_D3': {'Slater Koekkoek': 'LD', 'Tyson Barrie': 'RD'},
#  'Oilers_F1': {'Connor McDavid': 'C',
#                'Ryan Nugent-Hopkins': 'LW',
#                'Zack Kassian': 'RW'},
#  'Oilers_F2': {'Dominik Kahun': 'LW',
#                'Kailer Yamamoto': 'RW',
#                'Leon Draisaitl': 'C'},
#  'Oilers_F3': {'Jesse Puljujarvi': 'RW',
#                'Josh Archibald': 'LW',
#                'Kyle Turris': 'C'},
#  'Oilers_F4': {'Alex Chiasson': 'RW',
#                'Devin Shore': 'LW',
#                'Jujhar Khaira': 'C'},
#  'Oilers_G1': {'Mikko Koskinen': 'G'},
#  'Oilers_G2': {'Stuart Skinner': 'G'},
#  'Oilers_IR': {'James Neal': 'IR', 'Oscar Klefbom': 'IR'},
#  'Oilers_PP1': {'Alex Chiasson': 'LW',
#                 'Connor McDavid': 'C',
#                 'Leon Draisaitl': 'RD',
#                 'Ryan Nugent-Hopkins': 'RW',
#                 'Tyson Barrie': 'LD'},
#  'Oilers_PP2': {'Darnell Nurse': 'RD',
#                 'Ethan Bear': 'LD',
#                 'Jesse Puljujarvi': 'RW',
#                 'Kyle Turris': 'C',
#                 'Tyler Ennis': 'LW'},
#  'Panthers_D1': {'Aaron Ekblad': 'RD', 'MacKenzie Weegar': 'LD'},
#  'Panthers_D2': {'Anton Stralman': 'RD', 'Riley Stillman': 'LD'},
#  'Panthers_D3': {'Gustav Forsling': 'LD', 'Radko Gudas': 'RD'},
#  'Panthers_F1': {'Aleksander Barkov': 'C',
#                  'Anthony Duclair': 'RW',
#                  'Carter Verhaeghe': 'LW'},
#  'Panthers_F2': {'Alexander Wennberg': 'C',
#                  'Jonathan Huberdeau': 'LW',
#                  'Patric Hornqvist': 'RW'},
#  'Panthers_F3': {'Eetu Luostarinen': 'C',
#                  'Frank Vatrano': 'LW',
#                  'Owen Tippett': 'RW'},
#  'Panthers_F4': {'Brett Connolly': 'RW',
#                  'Noel Acciari': 'C',
#                  'Vinnie Hinostroza': 'LW'},
#  'Panthers_G1': {'Sergei Bobrovsky': 'G'},
#  'Panthers_G2': {'Chris Driedger': 'G'},
#  'Panthers_IR': {'Markus Nutivaara': 'IR'},
#  'Panthers_PP1': {'Aaron Ekblad': 'LD',
#                   'Aleksander Barkov': 'C',
#                   'Anthony Duclair': 'RD',
#                   'Jonathan Huberdeau': 'RW',
#                   'Patric Hornqvist': 'LW'},
#  'Panthers_PP2': {'Alexander Wennberg': 'C',
#                   'Carter Verhaeghe': 'LW',
#                   'Frank Vatrano': 'RW',
#                   'Gustav Forsling': 'RD',
#                   'Owen Tippett': 'LD'},
#  'Penguins_D1': {'Brian Dumoulin': 'LD', 'Kris Letang': 'RD'},
#  'Penguins_D2': {'John Marino': 'RD', 'Marcus Pettersson': 'LD'},
#  'Penguins_D3': {'Chad Ruhwedel': 'RD', 'Michael Matheson': 'LD'},
#  'Penguins_F1': {'Evan Rodrigues': 'RW',
#                  'Jake Guentzel': 'LW',
#                  'Sidney Crosby': 'C'},
#  'Penguins_F2': {'Bryan Rust': 'RW',
#                  'Evgeni Malkin': 'C',
#                  'Jason Zucker': 'LW'},
#  'Penguins_F3': {'Brandon Tanev': 'RW',
#                  'Jared McCann': 'LW',
#                  'Mark Jankowski': 'C'},
#  'Penguins_F4': {'Colton Sceviour': 'RW',
#                  'Sam Lafferty': 'LW',
#                  'Teddy Blueger': 'C'},
#  'Penguins_G1': {'Tristan Jarry': 'G'},
#  'Penguins_G2': {'Casey DeSmith': 'G'},
#  'Penguins_IR': {'Kasperi Kapanen': 'IR', 'Zach Aston-Reese': 'IR'},
#  'Penguins_PP1': {'Bryan Rust': 'LW',
#                   'Evgeni Malkin': 'LD',
#                   'Jake Guentzel': 'RW',
#                   'Kris Letang': 'RD',
#                   'Sidney Crosby': 'C'},
#  'Penguins_PP2': {'Evan Rodrigues': 'RW',
#                   'Jared McCann': 'C',
#                   'Jason Zucker': 'LW',
#                   'John Marino': 'RD',
#                   'Marcus Pettersson': 'LD'},
#  'Predators_D1': {'Roman Josi': 'LD', 'Ryan Ellis': 'RD'},
#  'Predators_D2': {'Dante Fabbro': 'RD', 'Mattias Ekholm': 'LD'},
#  'Predators_D3': {'Mark Borowiecki': 'LD', 'Matt Benning': 'RD'},
#  'Predators_F1': {'Filip Forsberg': 'LW',
#                   'Ryan Johansen': 'C',
#                   'Viktor Arvidsson': 'RW'},
#  'Predators_F2': {'Erik Haula': 'LW', 'Luke Kunin': 'RW', 'Matt Duchene': 'C'},
#  'Predators_F3': {'Colton Sissons': 'C',
#                   'Nick Cousins': 'LW',
#                   'Rocco Grimaldi': 'RW'},
#  'Predators_F4': {'Brad Richardson': 'C',
#                   'Calle Jarnkrok': 'RW',
#                   'Cole Smith': 'LW'},
#  'Predators_G1': {'Juuse Saros': 'G'},
#  'Predators_G2': {'Pekka Rinne': 'G'},
#  'Predators_IR': {'Mikael Granlund': 'IR'},
#  'Predators_PP1': {'Filip Forsberg': 'LD',
#                    'Matt Duchene': 'RW',
#                    'Roman Josi': 'RD',
#                    'Ryan Johansen': 'C',
#                    'Viktor Arvidsson': 'LW'},
#  'Predators_PP2': {'Calle Jarnkrok': 'LW',
#                    'Dante Fabbro': 'RD',
#                    'Erik Haula': 'RW',
#                    'Luke Kunin': 'C',
#                    'Ryan Ellis': 'LD'},
#  'Rangers_D1': {'Jacob Trouba': 'RD', 'Ryan Lindgren': 'LD'},
#  'Rangers_D2': {'Adam Fox': 'RD', 'Jack Johnson': 'LD'},
#  'Rangers_D3': {'Brendan Smith': 'RD', "K'Andre Miller": 'LD'},
#  'Rangers_F1': {'Chris Kreider': 'LW',
#                 'Mika Zibanejad': 'C',
#                 'Pavel Buchnevich': 'RW'},
#  'Rangers_F2': {'Alexis Lafreniere': 'RW',
#                 'Artemi Panarin': 'LW',
#                 'Ryan Strome': 'C'},
#  'Rangers_F3': {'Filip Chytil': 'C',
#                 'Kaapo Kakko': 'RW',
#                 'Phil Di Giuseppe': 'LW'},
#  'Rangers_F4': {'Brendan Lemieux': 'LW',
#                 'Brett Howden': 'C',
#                 'Julien Gauthier': 'RW'},
#  'Rangers_G1': {'Igor Shesterkin': 'G'},
#  'Rangers_G2': {'Alexandar Georgiev': 'G'},
#  'Rangers_IR': {},
#  'Rangers_PP1': {'Adam Fox': 'RD',
#                  'Artemi Panarin': 'LD',
#                  'Chris Kreider': 'LW',
#                  'Mika Zibanejad': 'C',
#                  'Ryan Strome': 'RW'},
#  'Rangers_PP2': {'Alexis Lafreniere': 'RW',
#                  'Brendan Lemieux': 'LW',
#                  'Brett Howden': 'C',
#                  'Jacob Trouba': 'RD',
#                  'Pavel Buchnevich': 'LD'},
#  'Sabres_D1': {'Jake McCabe': 'LD', 'Rasmus Ristolainen': 'RD'},
#  'Sabres_D2': {'Brandon Montour': 'RD', 'Rasmus Dahlin': 'LD'},
#  'Sabres_D3': {'Colin Miller': 'LD', 'Henri Jokiharju': 'RD'},
#  'Sabres_F1': {'Jack Eichel': 'C', 'Tage Thompson': 'RW', 'Taylor Hall': 'LW'},
#  'Sabres_F2': {'Eric Staal': 'C',
#                'Sam Reinhart': 'RW',
#                'Victor Olofsson': 'LW'},
#  'Sabres_F3': {'Cody Eakin': 'C', 'Dylan Cozens': 'RW', 'Tobias Rieder': 'LW'},
#  'Sabres_F4': {'Curtis Lazar': 'C',
#                'Jeff Skinner': 'LW',
#                'Riley Sheahan': 'RW'},
#  'Sabres_G1': {'Linus Ullmark': 'G'},
#  'Sabres_G2': {'Carter Hutton': 'G'},
#  'Sabres_IR': {'Eric Staal': 'IR',
#                'Kyle Okposo': 'IR',
#                'Zemgus Girgensons': 'IR'},
#  'Sabres_PP1': {'Jack Eichel': 'C',
#                 'Rasmus Dahlin': 'LD',
#                 'Sam Reinhart': 'LW',
#                 'Taylor Hall': 'RW',
#                 'Victor Olofsson': 'RD'},
#  'Sabres_PP2': {'Dylan Cozens': 'C',
#                 'Eric Staal': 'RW',
#                 'Jeff Skinner': 'LW',
#                 'Rasmus Ristolainen': 'RD',
#                 'Tage Thompson': 'LD'},
#  'Senators_D1': {'Erik Gudbranson': 'RD', 'Thomas Chabot': 'LD'},
#  'Senators_D2': {'Christian Wolanin': 'LD', 'Nikita Zaitsev': 'RD'},
#  'Senators_D3': {'Braydon Coburn': 'LD', 'Josh Brown': 'RD'},
#  'Senators_F1': {'Brady Tkachuk': 'LW',
#                  'Drake Batherson': 'RW',
#                  'Josh Norris': 'C'},
#  'Senators_F2': {'Derek Stepan': 'C',
#                  'Evgenii Dadonov': 'RW',
#                  'Tim Stuetzle': 'LW'},
#  'Senators_F3': {'Chris Tierney': 'C', 'Connor Brown': 'RW', 'Nick Paul': 'LW'},
#  'Senators_F4': {'Artem Anisimov': 'C',
#                  'Austin Watson': 'RW',
#                  'Cedric Paquette': 'LW'},
#  'Senators_G1': {'Matt Murray': 'G'},
#  'Senators_G2': {'Marcus Hogberg': 'G'},
#  'Senators_IR': {'Erik Brannstrom': 'IR'},
#  'Senators_PP1': {'Brady Tkachuk': 'C',
#                   'Drake Batherson': 'LW',
#                   'Evgenii Dadonov': 'RW',
#                   'Josh Norris': 'RD',
#                   'Thomas Chabot': 'LD'},
#  'Senators_PP2': {'Chris Tierney': 'LW',
#                   'Christian Wolanin': 'LD',
#                   'Connor Brown': 'RD',
#                   'Derek Stepan': 'C',
#                   'Tim Stuetzle': 'RW'},
#  'Sharks_D1': {'Erik Karlsson': 'RD', 'Marc-Edouard Vlasic': 'LD'},
#  'Sharks_D2': {'Brent Burns': 'RD', 'Mario Ferraro': 'LD'},
#  'Sharks_D3': {'Nicolas Meloche': 'RD', 'Nikolai Knyzhov': 'LD'},
#  'Sharks_F1': {'Kevin Labanc': 'RW', 'Logan Couture': 'C', 'Timo Meier': 'LW'},
#  'Sharks_F2': {'Evander Kane': 'RW', 'John Leonard': 'LW', 'Tomas Hertl': 'C'},
#  'Sharks_F3': {'Matthew Nieto': 'RW', 'Noah Gregor': 'C', 'Ryan Donato': 'LW'},
#  'Sharks_F4': {'Joel Kellman': 'C',
#                'Marcus Sorensen': 'RW',
#                'Patrick Marleau': 'LW'},
#  'Sharks_G1': {'Martin Jones': 'G'},
#  'Sharks_G2': {'Devan Dubnyk': 'G'},
#  'Sharks_IR': {'Radim Simek': 'IR'},
#  'Sharks_PP1': {'Brent Burns': 'LD',
#                 'Erik Karlsson': 'RD',
#                 'Evander Kane': 'LW',
#                 'Logan Couture': 'RW',
#                 'Tomas Hertl': 'C'},
#  'Sharks_PP2': {'John Leonard': 'LW',
#                 'Kevin Labanc': 'RW',
#                 'Mario Ferraro': 'RD',
#                 'Ryan Donato': 'C',
#                 'Timo Meier': 'LD'},
#  'Stars_D1': {'Esa Lindell': 'LD', 'John Klingberg': 'RD'},
#  'Stars_D2': {'Jamie Oleksiak': 'LD', 'Miro Heiskanen': 'RD'},
#  'Stars_D3': {'Andrej Sekera': 'LD', 'Mark Pysyk': 'RD'},
#  'Stars_F1': {'Denis Gurianov': 'RW', 'Jamie Benn': 'LW', 'Roope Hintz': 'C'},
#  'Stars_F2': {'Alexander Radulov': 'RW',
#               'Joe Pavelski': 'C',
#               'Joel Kiviranta': 'LW'},
#  'Stars_F3': {'Andrew Cogliano': 'LW',
#               'Blake Comeau': 'RW',
#               'Radek Faksa': 'C'},
#  'Stars_F4': {'Jason Dickinson': 'C',
#               'Justin Dowling': 'RW',
#               'Nicholas Caamano': 'LW'},
#  'Stars_G1': {'Anton Khudobin': 'G'},
#  'Stars_G2': {'Jake Oettinger': 'G'},
#  'Stars_IR': {'Ben Bishop': 'IR',
#               'Martin Hanzal': 'IR',
#               'Stephen Johns': 'IR',
#               'Tyler Seguin': 'IR'},
#  'Stars_PP1': {'Alexander Radulov': 'RW',
#                'Denis Gurianov': 'RD',
#                'Jamie Benn': 'LW',
#                'Joe Pavelski': 'C',
#                'John Klingberg': 'LD'},
#  'Stars_PP2': {'Esa Lindell': 'RD',
#                'Joel Kiviranta': 'RW',
#                'Miro Heiskanen': 'LD',
#                'Radek Faksa': 'LW',
#                'Roope Hintz': 'C'},
#  'Wild_D1': {'Mathew Dumba': 'RD', 'Ryan Suter': 'LD'},
#  'Wild_D2': {'Jared Spurgeon': 'LD', 'Jonas Brodin': 'RD'},
#  'Wild_D3': {'Carson Soucy': 'RD', 'Greg Pateryn': 'LD'},
#  'Wild_F1': {'Kirill Kaprizov': 'RW',
#              'Nick Bjugstad': 'C',
#              'Zach Parise': 'LW'},
#  'Wild_F2': {'Kevin Fiala': 'RW', 'Marcus Johansson': 'LW', 'Nick Bonino': 'C'},
#  'Wild_F3': {'Joel Eriksson Ek': 'C',
#              'Jordan Greenway': 'LW',
#              'Marcus Foligno': 'RW'},
#  'Wild_F4': {'Nico Sturm': 'LW', 'Ryan Hartman': 'RW', 'Victor Rask': 'C'},
#  'Wild_G1': {'Cam Talbot': 'G'},
#  'Wild_G2': {'Kaapo Kahkonen': 'G'},
#  'Wild_IR': {'Alex Stalock': 'IR', 'Mats Zuccarello': 'IR'},
#  'Wild_PP1': {'Jared Spurgeon': 'RD',
#               'Kevin Fiala': 'RW',
#               'Kirill Kaprizov': 'LW',
#               'Mathew Dumba': 'LD',
#               'Zach Parise': 'C'},
#  'Wild_PP2': {'Jordan Greenway': 'LW',
#               'Marcus Johansson': 'LD',
#               'Nick Bjugstad': 'RW',
#               'Nick Bonino': 'C',
#               'Ryan Suter': 'RD'},
#  'Wings_D1': {'Filip Hronek': 'RD', 'Patrik Nemeth': 'LD'},
#  'Wings_D2': {'Dan DeKeyser': 'LD', 'Jon Merrill': 'RD'},
#  'Wings_D3': {'Marc Staal': 'LD', 'Troy Stecher': 'RD'},
#  'Wings_F1': {'Anthony Mantha': 'RW',
#               'Dylan Larkin': 'C',
#               'Tyler Bertuzzi': 'LW'},
#  'Wings_F2': {'Filip Zadina': 'RW',
#               'Robby Fabbri': 'C',
#               'Vladislav Namestnikov': 'LW'},
#  'Wings_F3': {'Mathias Brome': 'LW',
#               'Sam Gagner': 'RW',
#               'Valtteri Filppula': 'C'},
#  'Wings_F4': {'Adam Erne': 'RW', 'Frans Nielsen': 'LW', 'Luke Glendening': 'C'},
#  'Wings_G1': {'Jonathan Bernier': 'G'},
#  'Wings_G2': {'Thomas Greiss': 'G'},
#  'Wings_IR': {'Adam Erne': 'IR', 'Bobby Ryan': 'IR', 'Darren Helm': 'IR'},
#  'Wings_PP1': {'Anthony Mantha': 'RD',
#                'Dan DeKeyser': 'LD',
#                'Dylan Larkin': 'RW',
#                'Tyler Bertuzzi': 'LW',
#                'Vladislav Namestnikov': 'C'},
#  'Wings_PP2': {'Filip Hronek': 'LD',
#                'Filip Zadina': 'RW',
#                'Jon Merrill': 'RD',
#                'Robby Fabbri': 'LW',
#                'Sam Gagner': 'C'}}

# %%
with open('./input/lineCombinations.json', 'w') as fp:
    json.dump(line_combinations, fp)
